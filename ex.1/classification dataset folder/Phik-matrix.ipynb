# %% [markdown]
# 0.0 - 0.1 → Very weak or no correlation.
# 0.1 - 0.3 → Weak correlation.
# 0.3 - 0.5 → Moderate correlation.
# 0.5 - 0.7 → Strong correlation.
# 0.7 - 1.0 → Very strong correlation.

# %%
import pandas as pd
from phik import resources, report

df = pd.read_csv("final_pet_food_dataset.csv")
phik_corr = df.phik_matrix()
print(phik_corr)
# Out:
# interval columns not set, guessing: ['pet_id', 'customer_id', 'wet_food_order_number', 'pet_has_active_subscription', 'pet_food_tier', 'pet_allergen_list', 'pet_fav_flavour_list', 'pet_health_issue_list', 'neutered', 'gender', 'pet_breed_size', 'signup_promo', 'ate_wet_food_pre_tails', 'dry_food_brand_pre_tails', 'pet_life_stage_at_order', 'total_order_kcal', 'total_web_sessions', 'total_web_sessions_since_last_order', 'total_minutes_on_website']
#                                        pet_id  customer_id  \
# pet_id                               1.000000     0.000000
# customer_id                          0.000000     1.000000
# wet_food_order_number                0.000000     0.018819
# pet_has_active_subscription          0.000000     0.027072
# pet_food_tier                        0.061143     0.000000
# pet_allergen_list                    0.049723     0.000000
# pet_fav_flavour_list                 0.081174     0.010631
# pet_health_issue_list                0.092382     0.012614
# neutered                             0.000000     0.014678
# gender                               0.099183     0.031506
# pet_breed_size                       0.084848     0.028441
# signup_promo                         0.132348     0.000000
# ate_wet_food_pre_tails               0.005451     0.000000
# dry_food_brand_pre_tails             0.106762     0.000000
# pet_life_stage_at_order              0.075137     0.050868
# total_order_kcal                     0.000000     0.039424
# total_web_sessions                   0.000000     0.011347
# total_web_sessions_since_last_order  0.022990     0.015618
# total_minutes_on_website             0.044469     0.027618
#
#                                      wet_food_order_number  \
# pet_id                                            0.000000
# customer_id                                       0.018819
# wet_food_order_number                             1.000000
# pet_has_active_subscription                       0.018638
# pet_food_tier                                     0.024149
# pet_allergen_list                                 0.000000
# pet_fav_flavour_list                              0.000000
# pet_health_issue_list                             0.014699
# neutered                                          0.150637
# gender                                            0.000000
# pet_breed_size                                    0.000000
# signup_promo                                      0.000000
# ate_wet_food_pre_tails                            0.714994
# dry_food_brand_pre_tails                          0.000000
# pet_life_stage_at_order                           0.005495
# total_order_kcal                                  0.036165
# total_web_sessions                                0.042335
# total_web_sessions_since_last_order               0.097816
# total_minutes_on_website                          0.020420
#
#                                      pet_has_active_subscription  \
# pet_id                                                  0.000000
# customer_id                                             0.027072
# wet_food_order_number                                   0.018638
# pet_has_active_subscription                             1.000000
# pet_food_tier                                           0.000000
# pet_allergen_list                                       0.000000
# pet_fav_flavour_list                                    0.000000
# pet_health_issue_list                                   0.000000
# neutered                                                0.081336
# gender                                                  0.000000
# pet_breed_size                                          0.000000
# signup_promo                                            0.000000
# ate_wet_food_pre_tails                                  0.041933
# dry_food_brand_pre_tails                                0.005977
# pet_life_stage_at_order                                 0.000000
# total_order_kcal                                        0.130335
# total_web_sessions                                      0.078853
# total_web_sessions_since_last_order                     0.149952
# total_minutes_on_website                                0.064319
#
#                                      pet_food_tier  pet_allergen_list  \
# pet_id                                    0.061143           0.049723
# customer_id                               0.000000           0.000000
# wet_food_order_number                     0.024149           0.000000
# pet_has_active_subscription               0.000000           0.000000
# pet_food_tier                             1.000000           0.012359
# pet_allergen_list                         0.012359           1.000000
# pet_fav_flavour_list                      0.000000           0.154467
# pet_health_issue_list                     0.186012           0.390468
# neutered                                  0.000000           0.000000
# gender                                    0.000000           0.000000
# pet_breed_size                            0.013914           0.016313
# signup_promo                              0.037579           0.000000
# ate_wet_food_pre_tails                    0.000000           0.000000
# dry_food_brand_pre_tails                  0.311689           0.037101
# pet_life_stage_at_order                   0.116997           0.016709
# total_order_kcal                          0.005900           0.000000
# total_web_sessions                        0.000000           0.007081
# total_web_sessions_since_last_order       0.025088           0.009937
# total_minutes_on_website                  0.028170           0.000000
#
#                                      pet_fav_flavour_list  \
# pet_id                                           0.081174
# customer_id                                      0.010631
# wet_food_order_number                            0.000000
# pet_has_active_subscription                      0.000000
# pet_food_tier                                    0.000000
# pet_allergen_list                                0.154467
# pet_fav_flavour_list                             1.000000
# pet_health_issue_list                            0.088293
# neutered                                         0.000000
# gender                                           0.083025
# pet_breed_size                                   0.030218
# signup_promo                                     0.024802
# ate_wet_food_pre_tails                           0.000000
# dry_food_brand_pre_tails                         0.079268
# pet_life_stage_at_order                          0.048688
# total_order_kcal                                 0.000000
# total_web_sessions                               0.022346
# total_web_sessions_since_last_order              0.023273
# total_minutes_on_website                         0.017066
#
#                                      pet_health_issue_list  neutered  \
# pet_id                                            0.092382  0.000000
# customer_id                                       0.012614  0.014678
# wet_food_order_number                             0.014699  0.150637
# pet_has_active_subscription                       0.000000  0.081336
# pet_food_tier                                     0.186012  0.000000
# pet_allergen_list                                 0.390468  0.000000
# pet_fav_flavour_list                              0.088293  0.000000
# pet_health_issue_list                             1.000000  0.000000
# neutered                                          0.000000  1.000000
# gender                                            0.040610  0.000000
# pet_breed_size                                    0.040949  0.000000
# signup_promo                                      0.013928  0.000000
# ate_wet_food_pre_tails                            0.018283  0.055656
# dry_food_brand_pre_tails                          0.028964  0.000000
# pet_life_stage_at_order                           0.376267  0.000000
# total_order_kcal                                  0.000000  0.060400
# total_web_sessions                                0.000000  0.050120
# total_web_sessions_since_last_order               0.000000  0.055347
# total_minutes_on_website                          0.012154  0.028523
#
#                                        gender  pet_breed_size  signup_promo  \
# pet_id                               0.099183        0.084848      0.132348
# customer_id                          0.031506        0.028441      0.000000
# wet_food_order_number                0.000000        0.000000      0.000000
# pet_has_active_subscription          0.000000        0.000000      0.000000
# pet_food_tier                        0.000000        0.013914      0.037579
# pet_allergen_list                    0.000000        0.016313      0.000000
# pet_fav_flavour_list                 0.083025        0.030218      0.024802
# pet_health_issue_list                0.040610        0.040949      0.013928
# neutered                             0.000000        0.000000      0.000000
# gender                               1.000000        0.037577      0.000000
# pet_breed_size                       0.037577        1.000000      0.010157
# signup_promo                         0.000000        0.010157      1.000000
# ate_wet_food_pre_tails               0.000000        0.007909      0.000000
# dry_food_brand_pre_tails             0.000000        0.044397      0.000000
# pet_life_stage_at_order              0.041649        0.004783      0.037221
# total_order_kcal                     0.000000        0.031428      0.015070
# total_web_sessions                   0.009283        0.000000      0.000000
# total_web_sessions_since_last_order  0.018802        0.020047      0.014720
# total_minutes_on_website             0.000000        0.000000      0.000000
#
#                                      ate_wet_food_pre_tails  \
# pet_id                                             0.005451
# customer_id                                        0.000000
# wet_food_order_number                              0.714994
# pet_has_active_subscription                        0.041933
# pet_food_tier                                      0.000000
# pet_allergen_list                                  0.000000
# pet_fav_flavour_list                               0.000000
# pet_health_issue_list                              0.018283
# neutered                                           0.055656
# gender                                             0.000000
# pet_breed_size                                     0.007909
# signup_promo                                       0.000000
# ate_wet_food_pre_tails                             1.000000
# dry_food_brand_pre_tails                           0.007407
# pet_life_stage_at_order                            0.021112
# total_order_kcal                                   0.136560
# total_web_sessions                                 0.035883
# total_web_sessions_since_last_order                0.044705
# total_minutes_on_website                           0.025730
#
#                                      dry_food_brand_pre_tails  \
# pet_id                                               0.106762
# customer_id                                          0.000000
# wet_food_order_number                                0.000000
# pet_has_active_subscription                          0.005977
# pet_food_tier                                        0.311689
# pet_allergen_list                                    0.037101
# pet_fav_flavour_list                                 0.079268
# pet_health_issue_list                                0.028964
# neutered                                             0.000000
# gender                                               0.000000
# pet_breed_size                                       0.044397
# signup_promo                                         0.000000
# ate_wet_food_pre_tails                               0.007407
# dry_food_brand_pre_tails                             1.000000
# pet_life_stage_at_order                              0.024057
# total_order_kcal                                     0.000000
# total_web_sessions                                   0.023360
# total_web_sessions_since_last_order                  0.017862
# total_minutes_on_website                             0.013464
#
#                                      pet_life_stage_at_order  \
# pet_id                                              0.075137
# customer_id                                         0.050868
# wet_food_order_number                               0.005495
# pet_has_active_subscription                         0.000000
# pet_food_tier                                       0.116997
# pet_allergen_list                                   0.016709
# pet_fav_flavour_list                                0.048688
# pet_health_issue_list                               0.376267
# neutered                                            0.000000
# gender                                              0.041649
# pet_breed_size                                      0.004783
# signup_promo                                        0.037221
# ate_wet_food_pre_tails                              0.021112
# dry_food_brand_pre_tails                            0.024057
# pet_life_stage_at_order                             1.000000
# total_order_kcal                                    0.015911
# total_web_sessions                                  0.000000
# total_web_sessions_since_last_order                 0.000000
# total_minutes_on_website                            0.000000
#
#                                      total_order_kcal  total_web_sessions  \
# pet_id                                       0.000000            0.000000
# customer_id                                  0.039424            0.011347
# wet_food_order_number                        0.036165            0.042335
# pet_has_active_subscription                  0.130335            0.078853
# pet_food_tier                                0.005900            0.000000
# pet_allergen_list                            0.000000            0.007081
# pet_fav_flavour_list                         0.000000            0.022346
# pet_health_issue_list                        0.000000            0.000000
# neutered                                     0.060400            0.050120
# gender                                       0.000000            0.009283
# pet_breed_size                               0.031428            0.000000
# signup_promo                                 0.015070            0.000000
# ate_wet_food_pre_tails                       0.136560            0.035883
# dry_food_brand_pre_tails                     0.000000            0.023360
# pet_life_stage_at_order                      0.015911            0.000000
# total_order_kcal                             1.000000            0.520876
# total_web_sessions                           0.520876            1.000000
# total_web_sessions_since_last_order          0.388311            0.753696
# total_minutes_on_website                     0.291312            0.633527
#
#                                      total_web_sessions_since_last_order  \
# pet_id                                                          0.022990
# customer_id                                                     0.015618
# wet_food_order_number                                           0.097816
# pet_has_active_subscription                                     0.149952
# pet_food_tier                                                   0.025088
# pet_allergen_list                                               0.009937
# pet_fav_flavour_list                                            0.023273
# pet_health_issue_list                                           0.000000
# neutered                                                        0.055347
# gender                                                          0.018802
# pet_breed_size                                                  0.020047
# signup_promo                                                    0.014720
# ate_wet_food_pre_tails                                          0.044705
# dry_food_brand_pre_tails                                        0.017862
# pet_life_stage_at_order                                         0.000000
# total_order_kcal                                                0.388311
# total_web_sessions                                              0.753696
# total_web_sessions_since_last_order                             1.000000
# total_minutes_on_website                                        0.804452
#
#                                      total_minutes_on_website
# pet_id                                               0.044469
# customer_id                                          0.027618
# wet_food_order_number                                0.020420
# pet_has_active_subscription                          0.064319
# pet_food_tier                                        0.028170
# pet_allergen_list                                    0.000000
# pet_fav_flavour_list                                 0.017066
# pet_health_issue_list                                0.012154
# neutered                                             0.028523
# gender                                               0.000000
# pet_breed_size                                       0.000000
# signup_promo                                         0.000000
# ate_wet_food_pre_tails                               0.025730
# dry_food_brand_pre_tails                             0.013464
# pet_life_stage_at_order                              0.000000
# total_order_kcal                                     0.291312
# total_web_sessions                                   0.633527
# total_web_sessions_since_last_order                  0.804452
# total_minutes_on_website                             1.000000
