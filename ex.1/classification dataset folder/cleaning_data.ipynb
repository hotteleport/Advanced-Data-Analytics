# %% [markdown]
# link to dataset: https://www.kaggle.com/code/fireballbyedimyrnmom/pet-food-customer-orders

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Load the dataset
file_path = 'pet_food_customer_orders.csv'
data = pd.read_csv(file_path)

# Display the first few rows to understand the dataset
data.head()
# Out:
#             customer_id               pet_id  pet_order_number  \
# 0  10574848487411271014  4466839344031767293                 2
# 1  10574848487411271014  4466839344031767293                 1
# 2  10574848487411271014  4466839344031767293                 8
# 3  10574848487411271014  4466839344031767293                 4
# 4  10574848487411271014  4466839344031767293                 9
#
#    wet_food_order_number  orders_since_first_wet_trays_order  \
# 0                    1.0                                 1.0
# 1                    NaN                                 NaN
# 2                    7.0                                 7.0
# 3                    3.0                                 3.0
# 4                    8.0                                 8.0
#
#    pet_has_active_subscription pet_food_tier            pet_signup_datetime  \
# 0                         True  superpremium  1970-01-01 00:00:01.552397819
# ...

# %%
# Reload the dataset to ensure we have the cleaned version
file_path = 'pet_food_customer_orders.csv'
data = pd.read_csv(file_path)

# Drop columns that are unlikely to be useful for classification
columns_to_drop = ["total_wet_food_updates", "total_wet_food_updates_since_last_order", "last_customer_support_ticket_date", "wet_tray_size", "wet_food_textures_in_order", 'pet_signup_datetime', 'last_customer_support_ticket_date', 'customer_id', 'pet_id', 'pet_allergen_list', 'pet_fav_flavour_list', "customer_support_ticket_category"]
data_cleaned = data.drop(columns=columns_to_drop)

# Convert all categorical columns to string type to avoid any type conflicts
for column in data_cleaned.select_dtypes(include=['object']).columns:
    data_cleaned[column] = data_cleaned[column].astype(str)



# Convert boolean columns to numeric (True -> 1, False -> 0)
data_cleaned['pet_has_active_subscription'] = data_cleaned['pet_has_active_subscription'].astype(int)

# Convert categorical columns to numeric using label encoding
data_cleaned['pet_food_tier'] = data_cleaned['pet_food_tier'].astype('category').cat.codes

# Converting categorical columns with multiple levels to dummy/one-hot encoding
data_cleaned = pd.get_dummies(data_cleaned, drop_first=True)

# Ensure all values are numeric and handle any columns with mixed data types
data_cleaned = data_cleaned.apply(pd.to_numeric, errors='ignore')


data.head(30)
# Out:
# C:\Users\Dell XPS 15\AppData\Local\Temp\ipykernel_17776\1008954769.py:25: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   data_cleaned = data_cleaned.apply(pd.to_numeric, errors='ignore')
#              customer_id                pet_id  pet_order_number  \
# 0   10574848487411271014   4466839344031767293                 2
# 1   10574848487411271014   4466839344031767293                 1
# 2   10574848487411271014   4466839344031767293                 8
# 3   10574848487411271014   4466839344031767293                 4
# 4   10574848487411271014   4466839344031767293                 9
# 5    6342772975217424401  11842806521695140337                 6
# 6    6342772975217424401  11842806521695140337                 3
# 7    6342772975217424401  11842806521695140337                 9
# 8    6342772975217424401  11842806521695140337                 1
# ...
